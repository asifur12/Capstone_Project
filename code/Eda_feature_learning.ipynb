# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


import altair as alt
from vega_datasets import data

# %%
#loading datasets and viewing first 5 data
df = pd.read_csv('all_combined_annual_death_by_cause.csv')

df.head()
# Out:
#        country code  year   meningitis     neoplasms  \
# 0  Afghanistan  AFG  2007  2932.558591  15924.782541
# 1  Afghanistan  AFG  2008  2730.846137  16147.839026
# 2  Afghanistan  AFG  2009  2460.186423  16382.558546
# 3  Afghanistan  AFG  2011  2326.767573  17093.515668
# 4  Afghanistan  AFG  2012  2254.492968  17521.930189
#
#    fire_heat_hot_substances     malaria      drowing  interpersonal_violence  \
# 0                481.219817  392.942607  2126.788535             3657.205757
# 1                462.180576  254.703403  1973.375893             3784.702895
# 2                448.300264  239.035635  1852.155239             3874.099828
# 3                447.884354  390.060248  1774.968476             4169.873038
# 4                445.226412   93.894201  1715.864705             4244.671108
#
#      hiv_aids  ...  chronic_kidney_disease  chronic_respiratory_deasease  \
# 0  148.276329  ...             4490.174240                   7221.773068
# ...

# %%
data.cars()
# Out:
#                           Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0    chevrolet chevelle malibu              18.0          8         307.0
# 1            buick skylark 320              15.0          8         350.0
# 2           plymouth satellite              18.0          8         318.0
# 3                amc rebel sst              16.0          8         304.0
# 4                  ford torino              17.0          8         302.0
# ..                         ...               ...        ...           ...
# 401            ford mustang gl              27.0          4         140.0
# 402                  vw pickup              44.0          4          97.0
# 403              dodge rampage              32.0          4         135.0
# 404                ford ranger              28.0          4         120.0
# 405                 chevy s-10              31.0          4         119.0
#
#      Horsepower  Weight_in_lbs  Acceleration       Year  Origin
# ...

# %%
d_2019 = df[df['year']==1990]
d_1990 = df[df['year']==2019]

# %%
df1920 = df[df.year.isin([1990, 2019])]

# %%
df1920
# Out:
#           country code  year   meningitis     neoplasms  \
# 9     Afghanistan  AFG  1990  2159.020125  11579.846609
# 29    Afghanistan  AFG  2019  1562.753712  21247.179493
# 30        Albania  ALB  1990   106.524016   2615.538327
# 59        Albania  ALB  2019    12.942107   4704.869298
# 60        Algeria  DZA  1990   838.502815  10570.893879
# ...           ...  ...   ...          ...           ...
# 5609        Yemen  YEM  2019   478.685747  12680.603220
# 5610       Zambia  ZMB  1990  4561.989879   4634.959520
# 5639       Zambia  ZMB  2019  2065.187886   9789.448939
# 5640     Zimbabwe  ZWE  1990  1131.964887   5976.590135
# 5669     Zimbabwe  ZWE  2019  1450.049724  12352.632022
#
#       fire_heat_hot_substances      malaria      drowing  \
# 9                   322.933792    93.375927  1370.130461
# 29                  484.643007   530.455749  1687.001743
# 30                   31.290685     0.000000   146.769757
# 59                   17.738090     0.000000    35.800124
# ...

# %%
df_plot = pd.DataFrame()

# %%
df_plot['1990'] = df1920[df1920[ 'year']==1990].chronic_kidney_disease.values

# %%
df_plot['2019'] = df1920[df1920[ 'year']==2019].chronic_kidney_disease.values

# %%
df_plot['country'] = df['country']

# %%
df_plot['continent'] = df['continent']

# %%
df_plot.isnull().sum()
# Out:
# 1990         0
# 2019         0
# country      0
# continent    0
# dtype: int64

# %%
df_plot.head()
# Out:
#           1990         2019      country continent
# 0  3709.246259  5637.354930  Afghanistan      Asia
# 1   240.597515   328.787658  Afghanistan      Asia
# 2  3559.486330  8201.390952  Afghanistan      Asia
# 3     8.196850    25.675316  Afghanistan      Asia
# 4     4.169122    16.041086  Afghanistan      Asia

# %%
import plotly.express as px

fig = px.scatter( x = df_plot['1990'], y = df_plot['2019'],  labels= '2019', title= 'Kidney disease 1990 vs 2019')
fig.show()

# %%
plt.figure(figsize = (16,8))
sns.scatterplot(df_plot['1990'], df_plot['2019'], hue=df_plot.continent,markers='dot')
# Out:
# C:\Users\asifu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='1990', ylabel='2019'>

# %%
df1920.year.unique()
# Out:
# array([1990, 2019], dtype=int64)

# %%
import seaborn as sns

# %%
df.columns
# Out:
# Index(['country', 'code', 'year', 'meningitis', 'neoplasms',
#        'fire_heat_hot_substances', 'malaria', 'drowing',
#        'interpersonal_violence', 'hiv_aids', 'drug_use_disorders',
#        'tuberculosis', 'road_injuries', 'maternal_disorders',
#        'lower_respiratory_infection', 'neonatal_disorder',
#        'alcohol_use_disorders', 'force_of_nature', 'diarrheal',
#        'environmental_heat_cold', 'nutritional_deficiencies', 'self_harm',
#        'conflict_and_terrorism', 'diabetes_mellitus', 'poisoning',
#        'protein_energy_malnutrition', 'cardiovascular_diseases',
#        'chronic_kidney_disease', 'chronic_respiratory_deasease',
#        'cirrohosis_liver_deasease', 'digestive_disease', 'acute_hepatitis',
#        'alzhimers_disease', 'parkinsons_disease', 'PopTotal', 'gdp-per-capita',
#        'continent'],
#       dtype='object')

# %%
df_disease = df[['year',  'cardiovascular_diseases','chronic_kidney_disease','cirrohosis_liver_deasease',
    
       'neoplasms', 'drug_use_disorders','alzhimers_disease', 'parkinsons_disease','diabetes_mellitus' ]]

# %%
df_disease.head()
# Out:
#    year  cardiovascular_diseases  chronic_kidney_disease  \
# 0  2007             53962.251859             4490.174240
# 1  2008             54050.644196             4533.825139
# 2  2009             53964.195557             4596.974422
# 3  2011             54347.266593             4784.629776
# 4  2012             54868.120368             4845.667028
#
#    cirrohosis_liver_deasease     neoplasms  drug_use_disorders  \
# 0                3345.814979  15924.782541          251.830065
# 1                3316.354776  16147.839026          261.391617
# 2                3291.158847  16382.558546          269.845287
# 3                3317.891662  17093.515668          292.312638
# 4                3352.846566  17521.930189          304.570153
#
#    alzhimers_disease  parkinsons_disease  diabetes_mellitus
# 0             1402.0               450.0        3188.769589
# 1             1424.0               455.0        3260.816092
# ...

# %%
df_disease.set_index('year', inplace = True)

plt.figure(figsize = (20,12))
sns.lineplot(data=df_disease, )
plt.savefig('images/disease.jpg', dpi = 250,)

# %%
df_disease_decreasing = df[['year', 'meningitis','drowing', 'tuberculosis', 'maternal_disorders',  'diarrheal','nutritional_deficiencies' ]]

# %%
df_disease_decreasing.set_index('year', inplace = True)

plt.figure(figsize = (20,12))
sns.lineplot(data=df_disease_decreasing,palette='Paired' )
plt.savefig('images/disease.jpg', dpi = 250,)

# %%
df.columns
# Out:
# Index(['country', 'code', 'year', 'meningitis', 'neoplasms',
#        'fire_heat_hot_substances', 'malaria', 'drowing',
#        'interpersonal_violence', 'hiv_aids', 'drug_use_disorders',
#        'tuberculosis', 'road_injuries', 'maternal_disorders',
#        'lower_respiratory_infection', 'neonatal_disorder',
#        'alcohol_use_disorders', 'force_of_nature', 'diarrheal',
#        'environmental_heat_cold', 'nutritional_deficiencies', 'self_harm',
#        'conflict_and_terrorism', 'diabetes_mellitus', 'poisoning',
#        'protein_energy_malnutrition', 'cardiovascular_diseases',
#        'chronic_kidney_disease', 'chronic_respiratory_deasease',
#        'cirrohosis_liver_deasease', 'digestive_disease', 'acute_hepatitis',
#        'alzhimers_disease', 'parkinsons_disease', 'PopTotal', 'gdp-per-capita',
#        'continent'],
#       dtype='object')

# %%
d_1990.isnull().sum()
# Out:
# country                          0
# code                             0
# year                             0
# meningitis                       0
# neoplasms                        0
# fire_heat_hot_substances         0
# malaria                          0
# drowing                          0
# interpersonal_violence           0
# hiv_aids                         0
# drug_use_disorders               0
# tuberculosis                     0
# road_injuries                    0
# maternal_disorders               0
# lower_respiratory_infection      0
# neonatal_disorder                0
# alcohol_use_disorders            0
# force_of_nature                  0
# diarrheal                        0
# environmental_heat_cold          0
# nutritional_deficiencies         0
# self_harm                        0
# conflict_and_terrorism           0
# diabetes_mellitus                0
# poisoning                        0
# protein_energy_malnutrition      0
# cardiovascular_diseases          0
# ...

# %%
d_1990.shape
# Out:
# (189, 37)

# %%
d_2019.shape
# Out:
# (189, 37)

# %%
df.head()
# Out:
#        country code  year   meningitis     neoplasms  \
# 0  Afghanistan  AFG  2007  2932.558591  15924.782541
# 1  Afghanistan  AFG  2008  2730.846137  16147.839026
# 2  Afghanistan  AFG  2009  2460.186423  16382.558546
# 3  Afghanistan  AFG  2011  2326.767573  17093.515668
# 4  Afghanistan  AFG  2012  2254.492968  17521.930189
#
#    fire_heat_hot_substances     malaria      drowing  interpersonal_violence  \
# 0                481.219817  392.942607  2126.788535             3657.205757
# 1                462.180576  254.703403  1973.375893             3784.702895
# 2                448.300264  239.035635  1852.155239             3874.099828
# 3                447.884354  390.060248  1774.968476             4169.873038
# 4                445.226412   93.894201  1715.864705             4244.671108
#
#      hiv_aids  ...  chronic_kidney_disease  chronic_respiratory_deasease  \
# 0  148.276329  ...             4490.174240                   7221.773068
# ...

# %%
df_19 = df[df['year'] == 2019]

# %%
df_19.groupby('country')

# %%
df_19.head()
# Out:
#             country code  year   meningitis     neoplasms  \
# 29      Afghanistan  AFG  2019  1562.753712  21247.179493
# 59          Albania  ALB  2019    12.942107   4704.869298
# 89          Algeria  DZA  2019   291.540318  23816.158080
# 119  American Samoa  ASM  2019     0.670758     68.351118
# 149         Andorra  AND  2019     0.110482    229.599383
#
#      fire_heat_hot_substances     malaria      drowing  \
# 29                 484.643007  530.455749  1687.001743
# 59                  17.738090    0.000000    35.800124
# 89                 781.752166    0.082398   525.644593
# 119                  0.343981    0.000000     3.734388
# 149                  0.389725    0.000000     0.348289
#
#      interpersonal_violence    hiv_aids  ...  chronic_kidney_disease  \
# 29              5015.352561  317.682004  ...             5637.354930
# 59                56.968646    1.646465  ...              328.787658
# 89               459.443033  263.550726  ...             8201.390952
# ...

# %%
df_19.agg(['max'])
# Out:
#       country code  year    meningitis     neoplasms  \
# max  Zimbabwe  ZWE  2019  44913.669874  2.716551e+06
#
#      fire_heat_hot_substances        malaria       drowing  \
# max              25876.386337  191106.092457  56523.951936
#
#      interpersonal_violence       hiv_aids  ...  chronic_kidney_disease  \
# max            65907.238811  143850.630286  ...           222921.855771
#
#      chronic_respiratory_deasease  cirrohosis_liver_deasease  \
# max                  1.168381e+06              270036.758435
#
#      digestive_disease  acute_hepatitis  alzhimers_disease  \
# max      464913.929161          30987.0           320715.0
#
#      parkinsons_disease     PopTotal  gdp-per-capita      continent
# max             76990.0  1433783.692     113940.2374  South America
#
# [1 rows x 37 columns]

# %%
df_19.columns
# Out:
# Index(['country', 'code', 'year', 'meningitis', 'neoplasms',
#        'fire_heat_hot_substances', 'malaria', 'drowing',
#        'interpersonal_violence', 'hiv_aids', 'drug_use_disorders',
#        'tuberculosis', 'road_injuries', 'maternal_disorders',
#        'lower_respiratory_infection', 'neonatal_disorder',
#        'alcohol_use_disorders', 'force_of_nature', 'diarrheal',
#        'environmental_heat_cold', 'nutritional_deficiencies', 'self_harm',
#        'conflict_and_terrorism', 'diabetes_mellitus', 'poisoning',
#        'protein_energy_malnutrition', 'cardiovascular_diseases',
#        'chronic_kidney_disease', 'chronic_respiratory_deasease',
#        'cirrohosis_liver_deasease', 'digestive_disease', 'acute_hepatitis',
#        'alzhimers_disease', 'parkinsons_disease', 'PopTotal', 'gdp-per-capita',
#        'continent'],
#       dtype='object')

# %%
country = []
disease = []
amount = []

# %%
for col in df_19.drop(columns = ['country','code','year','continent']).columns:
    
    print(col,":",df.loc[df[col] == df[col].max(), "country"].values[0], df[col].max())
    country.append(df.loc[df[col] == df[col].max(), "country"].values[0])
    disease.append(col)
    amount.append(df[col].max())
# Out:
# meningitis : India 98357.81723766564
# neoplasms : China 2716551.4581777984
# fire_heat_hot_substances : India 25876.38633709609
# malaria : Nigeria 280603.8443604288
# drowing : China 153773.19325390703
# interpersonal_violence : Brazil 69639.55581122902
# hiv_aids : South Africa 305491.32771883026
# drug_use_disorders : United States 65716.75096561147
# tuberculosis : India 657514.770829565
# road_injuries : China 329236.6511845143
# maternal_disorders : India 107928.74630854132
# lower_respiratory_infection : India 690912.7976621813
# neonatal_disorder : India 852761.1771184963
# alcohol_use_disorders : Russia 55199.745853195855
# force_of_nature : Haiti 222641.00000000023
# diarrheal : India 1119476.5710235282
# environmental_heat_cold : Russia 29048.42047056429
# nutritional_deficiencies : India 268223.4359612415
# self_harm : China 220356.71977794296
# conflict_and_terrorism : Rwanda 503532.0
# diabetes_mellitus : India 273088.6662123979
# poisoning : China 30883.47878427474
# ...

# %%
max_disease = pd.DataFrame({
    'country':country,
    'disease':disease,
    'amount':amount
})

# %%
max_disease
# Out:
#           country                       disease        amount
# 0           India                    meningitis  9.835782e+04
# 1           China                     neoplasms  2.716551e+06
# 2           India      fire_heat_hot_substances  2.587639e+04
# 3         Nigeria                       malaria  2.806038e+05
# 4           China                       drowing  1.537732e+05
# 5          Brazil        interpersonal_violence  6.963956e+04
# 6    South Africa                      hiv_aids  3.054913e+05
# 7   United States            drug_use_disorders  6.571675e+04
# 8           India                  tuberculosis  6.575148e+05
# 9           China                 road_injuries  3.292367e+05
# 10          India            maternal_disorders  1.079287e+05
# 11          India   lower_respiratory_infection  6.909128e+05
# 12          India             neonatal_disorder  8.527612e+05
# 13         Russia         alcohol_use_disorders  5.519975e+04
# ...

# %%
plt.figure(figsize =(25,12) )
sns.barplot(y =max_disease.disease , x=max_disease.amount , hue = max_disease.country, saturation=100, palette='Set2' )
# Out:
# <AxesSubplot:xlabel='amount', ylabel='disease'>

# %%
group.head()
# Out:
#           country                      disease        amount
# 0           India                   meningitis  9.835782e+04
# 1           China                    neoplasms  2.716551e+06
# 2           India     fire_heat_hot_substances  2.587639e+04
# 3         Nigeria                      malaria  2.806038e+05
# 4           China                      drowing  1.537732e+05
# 5          Brazil       interpersonal_violence  6.963956e+04
# 6    South Africa                     hiv_aids  3.054913e+05
# 7   United States           drug_use_disorders  6.571675e+04
# 8           India                 tuberculosis  6.575148e+05
# 9           China                road_injuries  3.292367e+05
# 10          India           maternal_disorders  1.079287e+05
# 11          India  lower_respiratory_infection  6.909128e+05
# 13         Russia        alcohol_use_disorders  5.519975e+04
# 14          Haiti              force_of_nature  2.226410e+05
# ...

# %%
group.amount.describe()
# Out:
#                count          mean           std            min  \
# country
# Brazil           1.0  6.963956e+04           NaN   69639.555811
# China           10.0  1.123260e+06  1.490347e+06   30883.478784
# Haiti            1.0  2.226410e+05           NaN  222641.000000
# India           14.0  3.798971e+05  3.307241e+05   25876.386337
# Luxembourg       1.0  1.148892e+05           NaN  114889.180000
# Nigeria          1.0  2.806038e+05           NaN  280603.844360
# Russia           2.0  4.212408e+04  1.849178e+04   29048.420471
# Rwanda           1.0  5.035320e+05           NaN  503532.000000
# South Africa     1.0  3.054913e+05           NaN  305491.327719
# United States    1.0  6.571675e+04           NaN   65716.750966
#
#                          25%            50%           75%           max
# country
# Brazil          69639.555811   69639.555811  6.963956e+04  6.963956e+04
# China          170419.074885  324975.825592  1.416847e+06  4.584273e+06
# ...

# %%
df_19.columns
# Out:
# Index(['country', 'code', 'year', 'meningitis', 'neoplasms',
#        'fire_heat_hot_substances', 'malaria', 'drowing',
#        'interpersonal_violence', 'hiv_aids', 'drug_use_disorders',
#        'tuberculosis', 'road_injuries', 'maternal_disorders',
#        'lower_respiratory_infection', 'neonatal_disorder',
#        'alcohol_use_disorders', 'force_of_nature', 'diarrheal',
#        'environmental_heat_cold', 'nutritional_deficiencies', 'self_harm',
#        'conflict_and_terrorism', 'diabetes_mellitus', 'poisoning',
#        'protein_energy_malnutrition', 'cardiovascular_diseases',
#        'chronic_kidney_disease', 'chronic_respiratory_deasease',
#        'cirrohosis_liver_deasease', 'digestive_disease', 'acute_hepatitis',
#        'alzhimers_disease', 'parkinsons_disease', 'PopTotal', 'gdp-per-capita',
#        'continent'],
#       dtype='object')

# %%
df_19.dropna(inplace = True)

# %%
df_19.drop(columns = 'gdp-per-capita', inplace = True)

# %%
a = []
b = []
c = []

# %%
for col in df_19.drop(columns = ['country','code','year','continent']).columns:
    
    df_19.loc[:, col] = df_19.loc[:,col]/df_19.PopTotal
    a.append(df_19.loc[df_19[col] == df_19[col].max(), "country"].values[0])
    b.append(col)
    c.append(df_19[col].max())

# %%
by_pop = pd.DataFrame({
    'country':a,
    'disease':b,
    'amount':c
})

# %%
plt.figure(figsize =(25,12) )
sns.barplot(y =by_pop.disease , x=by_pop.amount , hue = by_pop.country, saturation=100,  )
# Out:
# <AxesSubplot:xlabel='amount', ylabel='disease'>

# %%
by_pop.sort_values(by = 'amount',ascending=False)
# Out:
#                      country                       disease     amount
# 23                  Bulgaria       cardiovascular_diseases  11.302586
# 6                    Lesotho                      hiv_aids   5.078255
# 1                    Hungary                     neoplasms   3.540913
# 20                      Fiji             diabetes_mellitus   1.938482
# 15                      Chad                     diarrheal   1.904574
# 8   Central African Republic                  tuberculosis   1.820255
# 12                      Mali             neonatal_disorder   1.628125
# 3               Sierra Leone                       malaria   1.499666
# 25                     Nepal  chronic_respiratory_deasease   1.426123
# 11                   Somalia   lower_respiratory_infection   1.343720
# 29                     Japan             alzhimers_disease   1.299650
# 31               Afghanistan                      PopTotal   1.000000
# ...

# %%
cancer = pd.read_csv('cancer_type.csv')

# %%
cancer.columns
# Out:
# Index(['country', 'year', 'liver_cancer', 'kidney_cancer',
#        'lip_and_oral_cavity_cancer', 'lung', 'larynx', 'gallbladder_biliary',
#        'malignant_skin', 'lukemia', 'hodgkin_lymphoma', 'multiple_myeloma',
#        'other', 'breast', 'prostate', 'thyroid', 'stomach', 'bladder',
#        'uterine', 'ovarian', 'cervical', 'brain', 'non_hodgkin_lymphoma',
#        'pancreatic', 'esophageal', 'testicular', 'nasopharynx',
#        'other_pharynx', 'colon', 'non_melanoma_skin', 'mesothelioma'],
#       dtype='object')

# %%
cancer.set_index(keys=)

# %%
cancer.columns

# %%
coll = [ 'liver_cancer', 'kidney_cancer',
       'lip_and_oral_cavity_cancer', 'lung', 'larynx', 'gallbladder_biliary',
       'malignant_skin', 'lukemia', 'hodgkin_lymphoma', 'multiple_myeloma',
       'other', 'breast', 'prostate', 'thyroid', 'stomach', 'bladder',
       'uterine', 'ovarian', 'cervical', 'brain', 'non_hodgkin_lymphoma',
       'pancreatic', 'esophageal', 'testicular', 'nasopharynx',
       'other_pharynx', 'colon', 'non_melanoma_skin', 'mesothelioma']

# %%
sns.lineplot(cancer)

# %%
df['gdp-per-capita'].describe()
# Out:
# count      5089.000000
# mean      17473.619046
# std       19203.611137
# min           1.960152
# 25%        3565.197807
# 50%       10656.163230
# 75%       24642.599620
# max      114889.180000
# Name: gdp-per-capita, dtype: float64

# %%
df.columns
# Out:
# Index(['country', 'code', 'year', 'meningitis', 'neoplasms',
#        'fire_heat_hot_substances', 'malaria', 'drowing',
#        'interpersonal_violence', 'hiv_aids', 'drug_use_disorders',
#        'tuberculosis', 'road_injuries', 'maternal_disorders',
#        'lower_respiratory_infection', 'neonatal_disorder',
#        'alcohol_use_disorders', 'force_of_nature', 'diarrheal',
#        'environmental_heat_cold', 'nutritional_deficiencies', 'self_harm',
#        'conflict_and_terrorism', 'diabetes_mellitus', 'poisoning',
#        'protein_energy_malnutrition', 'cardiovascular_diseases',
#        'chronic_kidney_disease', 'chronic_respiratory_deasease',
#        'cirrohosis_liver_deasease', 'digestive_disease', 'acute_hepatitis',
#        'alzhimers_disease', 'parkinsons_disease', 'PopTotal', 'gdp-per-capita',
#        'continent'],
#       dtype='object')

# %%
col = ['meningitis', 'neoplasms',
       'fire_heat_hot_substances', 'malaria', 'drowing',
       'interpersonal_violence', 'hiv_aids', 'drug_use_disorders',
       'tuberculosis', 'road_injuries', 'maternal_disorders',
       'lower_respiratory_infection', 'neonatal_disorder',
       'alcohol_use_disorders', 'force_of_nature', 'diarrheal',
       'environmental_heat_cold', 'nutritional_deficiencies', 'self_harm',
       'conflict_and_terrorism', 'diabetes_mellitus', 'poisoning',
       'protein_energy_malnutrition', 'cardiovascular_diseases',
       'chronic_kidney_disease', 'chronic_respiratory_deasease',
       'cirrohosis_liver_deasease', 'digestive_disease', 'acute_hepatitis',
       'alzhimers_disease', 'parkinsons_disease', 'PopTotal', 'gdp-per-capita']

# %%
for i in df[col]:
    plt.figure(figsize = (18,8))
    sns.lineplot(data = df, x = 'year', y = i)
    plt.title(i)
# Out:
# C:\Users\asifu\AppData\Local\Temp/ipykernel_17440/2104911870.py:2: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
classification = pd.read_csv('datasets/classification.csv')



developed = classification[classification['gdp_cat']=='yes']

undeveloped = classification[classification['gdp_cat']=='no']

# %%
for i in col:   
    plt.figure(figsize = (12,8))
    sns.lineplot(data = developed, x = 'year', y =i)
    sns.lineplot(data = undeveloped, x = 'year', y = i)
# Out:
# C:\Users\asifu\AppData\Local\Temp/ipykernel_17440/3107732365.py:2: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
sns.lineplot(developed.year,developed.neoplasms)
# Out:
# C:\Users\asifu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='year', ylabel='neoplasms'>

# %%
plt.figure(figsize = (12,8))

#create chart in each subplot
sns.lineplot(data=developed, x='year', y='neoplasms')
# Out:
# <AxesSubplot:xlabel='year', ylabel='neoplasms'>

# %%
sns.lineplot(data=undepoloped, x='year', y='neoplasms')
# Out:
# <AxesSubplot:xlabel='year', ylabel='neoplasms'>

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)

plt.plot(x = developed.year, y = developed.neoplasms)
plt.plot(x = undepoloped.year, y = undepoloped.neoplasms)
